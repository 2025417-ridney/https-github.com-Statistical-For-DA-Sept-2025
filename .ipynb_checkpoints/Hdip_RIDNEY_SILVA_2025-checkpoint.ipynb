# %% [markdown]
# # CA -Statistics for Data Analysis

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset

# %%
d = {'Diet-Group(D)': pd.Series([4.2, 6.0, 7.1, 6.1, 4.9, 5.8, 6.7, 6.0, 7.2, 4.4, 6.0, 5.3, 7.1, 6.5, 5.6]), 'Exercise-Group(E)': pd.Series([3.7, 4.1, 5.9, 4.4, 5.0, 4.7, 5.9, 4.2, 5.5, 3.7, 4.6, 4.8, 4.4, 5.9, 4.0]) }

# %% [markdown]
# # 1. Central tendency measure, variability measure

# %%
df = pd.DataFrame(d)
print("Mean Value",'\n', df.mean(),'\n' '\n', "Median Value:",'\n', df.median(), '\n' '\n', "Mode:", df.mode(), '\n' )
# Out:
# Mean Value
#  Diet-Group(D):        5.926667
# Exercise-Group(E):    4.720000
# dtype: float64
#
#  Median Value:
#  Diet-Group(D):        6.0
# Exercise-Group(E):    4.6
# dtype: float64
#
#  Mode:    Diet-Group(D):  Exercise-Group(E):
# 0             6.0                 5.9

# %%
print("standard deviation:",'\n',df.std())
# Out:
# standard deviation:
#  Diet-Group(D):        0.934625
# Exercise-Group(E):    0.772010
# dtype: float64

# %%
print("Variance of groups:",'\n', np.var(df)) #printing variance of both groups
# Out:
# Variance of groups:
#  Diet-Group(D):        0.815289
# Exercise-Group(E):    0.556267
# dtype: float64

# %%
# Loking at the dataset
df.head() #first 5 rows
# Out:
#    Diet-Group(D):  Exercise-Group(E):
# 0             4.2                 3.7
# 1             6.0                 4.1
# 2             7.1                 5.9
# 3             6.1                 4.4
# 4             4.9                 5.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, fill=True)

plt.title('PDF of Diet and Exercise Groups', fontsize=16)
plt.xlabel('Values', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()

# %% [markdown]
# # 2 - Probability distribution, Normal probability, Count and Unique

# %%
co = df.count() #total quantities
nu = df.nunique() #quantities of unique values

print("Number of unique values:",'\n', nu, 
      '\n''\n', "Count the total:", '\n', co)
# Out:
# Number of unique values:
#  Diet-Group(D):        12
# Exercise-Group(E):    11
# dtype: int64
#
#  Count the total
#  Diet-Group(D):        15
# Exercise-Group(E):    15
# dtype: int64

# %% [markdown]
# # 3 - Calculate Similarity

# %% [markdown]
# - [x] Euclidean Distance

# %%
e = np.sqrt(np.sum((df))) #Euclidean distance
print("Euclidean distance of bothe groups:", '\n' '\n', e)
# Out:
# Euclidean distance of bothe groups:
#
#  Diet-Group(D):        9.428680
# Exercise-Group(E):    8.414274
# dtype: float64

# %% [markdown]
# - [x] Covariance

# %%
c = df.cov()
print("Covariance of:", '\n', '\t', c)  # "c" means covariance variable

# "cov_de" means covariance of cov of 'd' and 'e' diet and exercise groups
cov_de = c.loc['Diet-Group(D)', 'Exercise-Group(E)']
print('\n', "Covariance Between 'Diet Group D' and 'Exercise Group E' is:", '\n', cov_de)


c_array = np.cov(df)  # "c_array" means covariance variable
print('\n', '\t', "Covariance of all array:",  '\n', c_array)
# Out:
# Covariance of:
#  	                     Diet-Group(D):  Exercise-Group(E):
# Diet-Group(D):            0.873524            0.475857
# Exercise-Group(E):        0.475857            0.596000
#
#  Covariance Between 'Diet Group D' and 'Exercise Group E' is:
#  0.475857142857143
#
#  	 Covariance of all array:
#  [[ 0.125  0.475  0.3    0.425 -0.025  0.275  0.2    0.45   0.425  0.175
#    0.35   0.125  0.675  0.15   0.4  ]
#  [ 0.475  1.805  1.14   1.615 -0.095  1.045  0.76   1.71   1.615  0.665
#    1.33   0.475  2.565  0.57   1.52 ]
#  [ 0.3    1.14   0.72   1.02  -0.06   0.66   0.48   1.08   1.02   0.42
#    0.84   0.3    1.62   0.36   0.96 ]
#  [ 0.425  1.615  1.02   1.445 -0.085  0.935  0.68   1.53   1.445  0.595
#    1.19   0.425  2.295  0.51   1.36 ]
#  [-0.025 -0.095 -0.06  -0.085  0.005 -0.055 -0.04  -0.09  -0.085 -0.035
#   -0.07  -0.025 -0.135 -0.03  -0.08 ]
#  [ 0.275  1.045  0.66   0.935 -0.055  0.605  0.44   0.99   0.935  0.385
#    0.77   0.275  1.485  0.33   0.88 ]
#  [ 0.2    0.76   0.48   0.68  -0.04   0.44   0.32   0.72   0.68   0.28
#    0.56   0.2    1.08   0.24   0.64 ]
#  [ 0.45   1.71   1.08   1.53  -0.09   0.99   0.72   1.62   1.53   0.63
#    1.26   0.45   2.43   0.54   1.44 ]
#  [ 0.425  1.615  1.02   1.445 -0.085  0.935  0.68   1.53   1.445  0.595
#    1.19   0.425  2.295  0.51   1.36 ]
#  [ 0.175  0.665  0.42   0.595 -0.035  0.385  0.28   0.63   0.595  0.245
#    0.49   0.175  0.945  0.21   0.56 ]
#  [ 0.35   1.33   0.84   1.19  -0.07   0.77   0.56   1.26   1.19   0.49
#    0.98   0.35   1.89   0.42   1.12 ]
#  [ 0.125  0.475  0.3    0.425 -0.025  0.275  0.2    0.45   0.425  0.175
#    0.35   0.125  0.675  0.15   0.4  ]
#  [ 0.675  2.565  1.62   2.295 -0.135  1.485  1.08   2.43   2.295  0.945
#    1.89   0.675  3.645  0.81   2.16 ]
#  [ 0.15   0.57   0.36   0.51  -0.03   0.33   0.24   0.54   0.51   0.21
#    0.42   0.15   0.81   0.18   0.48 ]
#  [ 0.4    1.52   0.96   1.36  -0.08   0.88   0.64   1.44   1.36   0.56
#    1.12   0.4    2.16   0.48   1.28 ]]

# %% [markdown]
# - [x] Correlation

# %%
correlation = np.corrcoef(df['Diet-Group(D)'], df['Exercise-Group(E)'])
print("Correlation", correlation)  # Correlation  between Diet Group and Exercise
# Out:
# Correlation [[1.         0.65950196]
#  [0.65950196 1.        ]]
