# %% [markdown]
# # Importing Libraries

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import statistics
from scipy.stats import skew
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import warnings

# import module Scikit-Learn provides functions for splitting data into training and test sets
from sklearn.model_selection import train_test_split

warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Dataset

# %%
# Importing the dataset
dataset = pd.read_csv('student_performance_dataset.csv')

# %%
# Loking at the dataset
dataset.head(100)
# Out:
#     Hours_Studied  Hours_Sleep  Caffeine_Intake Stress  Exam_Score
# 0            22.5          4.9                4     No        94.1
# 1            19.3          6.4                5     No        96.2
# 2            23.2          6.5                5     No        85.8
# 3            27.6          5.8                1    Yes        99.8
# 4            18.8          6.8                0    Yes        83.5
# ..            ...          ...              ...    ...         ...
# 95           12.7          7.6                3     No        78.6
# 96           21.5          5.7                4     No        88.2
# 97           21.3          7.2                3    Yes        83.5
# 98           20.0          7.1                0     No        92.0
# 99           18.8          5.3                0     No        90.7
#
# [100 rows x 5 columns]

# %%
dataset.describe(include='all') # summary overview of dataset
# Out:
#         Hours_Studied  Hours_Sleep  Caffeine_Intake Stress  Exam_Score
# count      100.000000   100.000000       100.000000    100  100.000000
# unique            NaN          NaN              NaN      2         NaN
# top               NaN          NaN              NaN     No         NaN
# freq              NaN          NaN              NaN     68         NaN
# mean        19.484000     7.009000         1.940000    NaN   88.735000
# std          4.540541     1.378998         1.625678    NaN    7.518037
# min          6.900000     4.100000         0.000000    NaN   61.300000
# 25%         17.000000     5.800000         1.000000    NaN   83.850000
# 50%         19.350000     7.100000         2.000000    NaN   88.600000
# 75%         22.050000     7.825000         3.000000    NaN   93.950000
# max         29.300000    10.000000         8.000000    NaN  100.000000

# %%
# Looking at unique values
dataset.nunique()
# Out:
# Hours_Studied      79
# Hours_Sleep        45
# Caffeine_Intake     7
# Stress              2
# Exam_Score         72
# dtype: int64

# %%
df = pd.DataFrame(dataset)# create a pd dataframe

rows = df.shape[0]  #number of rows
columns =  df.shape[1]  #number of comlumns
print("Dataset:",df.shape, "\nNumber of rows:", rows, "\nNumber of Columns:", columns)
# Out:
# Dataset: (100, 5)
# Number of rows: 100
# Number of Columns: 5

# %%
missing_values = df.isnull().values.any() #contains missing value
print("\n Contain Missing values: ?", missing_values)
print("\n Columns with missed values: \n", df.isna().any())
# Out:
#  Contain Missing values: ? False
#
#  Columns with missed values:
#  Hours_Studied      False
# Hours_Sleep        False
# Caffeine_Intake    False
# Stress             False
# Exam_Score         False
# dtype: bool

# %%
df.info()#identify the type of data to handle with
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Hours_Studied    100 non-null    float64
#  1   Hours_Sleep      100 non-null    float64
#  2   Caffeine_Intake  100 non-null    int64
#  3   Stress           100 non-null    object
#  4   Exam_Score       100 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 4.0+ KB

# %% [markdown]
# # Descriptive statistics

# %%
#mappin 'No' to 0 and 'Yes' to 1
df = pd.DataFrame(dataset)
df['Stress_Encoded'] = df['Stress'].map({'No': 0, 'Yes': 1})

# calculate for all numerical columns
mean = df.mean(numeric_only=True)
median = df.median(numeric_only=True)
mode = df.mode(numeric_only=True).iloc[0]

print("\n Mean (Average):\n", mean)
print("\n Median (Middle Value):\n", median)
print("\n Mode (Most Frequent):\n", mode)

std_value = df.std(numeric_only=True)
print("\n Standard Deviation:\n", std_value)
# Out:
#  Mean (Average):
#  Hours_Studied      19.484
# Hours_Sleep         7.009
# Caffeine_Intake     1.940
# Exam_Score         88.735
# Stress_Encoded      0.320
# dtype: float64
#
#  Median (Middle Value):
#  Hours_Studied      19.35
# Hours_Sleep         7.10
# Caffeine_Intake     2.00
# Exam_Score         88.60
# Stress_Encoded      0.00
# dtype: float64
#
#  Mode (Most Frequent):
#  Hours_Studied       17.7
# Hours_Sleep          7.3
# Caffeine_Intake      1.0
# Exam_Score         100.0
# Stress_Encoded       0.0
# Name: 0, dtype: float64
#
#  Standard Deviation:
#  Hours_Studied      4.540541
# Hours_Sleep        1.378998
# Caffeine_Intake    1.625678
# Exam_Score         7.518037
# Stress_Encoded     0.468826
# dtype: float64

# %% [markdown]
# # statistical graphics to better visualize

# %%
df['Stress_Status'] = df['Stress'].map({'No': 'Not Stressed', 'Yes': 'Stressed'})
sns.set_theme(style="whitegrid")

#Correlation between hours study vs sleep
plt.figure(figsize=(9, 4))
sns.scatterplot(
                data=df, x='Hours_Studied', y='Hours_Sleep', hue='Stress_Status', 
                palette={'Stressed': 'red', 'Not Stressed': 'green'}, s=100
                )
plt.title('Individual Habits: Study VS Sleep', fontsize=15)
plt.xlabel('Hours Studied')
plt.ylabel('Hours Sleep')
plt.show()

# %%
plt.figure(figsize=(9, 4))
average_df = df.melt(id_vars='Stress_Status', value_vars=['Hours_Studied', 'Hours_Sleep'])#comparison of averages
sns.barplot(data=average_df, x='variable', y='value', hue='Stress_Status', palette=['#006b3c', '#8B0000'], errorbar=None)
plt.title('Average time spent by Stress category', fontsize=15)
plt.ylabel('Average Hours')
plt.show()

# %%
plt.figure(figsize=(9, 4))
sns.histplot(data=df, x='Hours_Sleep', kde=True, color='skyblue', bins=10)
plt.axvline(df['Hours_Sleep'].mean(), color='red', 
            linestyle='-', label=f'Average: 
            {df["Hours_Sleep"].mean():.1f}h')
plt.axvline(df['Hours_Sleep'].median(), color='black', 
            linestyle='--', label=f'Typical: 
            {df["Hours_Sleep"].median():.1f}h')
plt.title('Sleep distribution for All students', fontsize=15)
plt.legend()
plt.show()

# %%
# --- CHART 4: BOX PLOT (Variance and Outliers) ---
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Hours_Studied', 'Hours_Sleep']], palette='Set2')
plt.title('Range of Student Habits (Min to Max)', fontsize=15)
plt.ylabel('Hours')
plt.show()

# %%
# 1. Set the visual style for professional reporting
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (14, 10)

# (Assume 'df' is your existing DataFrame with Stress_Encoded)
# For better legend labels, we use a descriptive 'Stress Status' column
df['Stress_Status'] = df['Stress_Encoded'].map({0: 'Not Stressed', 1: 'Stressed'})

# Create a figure with 4 subplots
fig, axes = plt.subplots(2, 2)
fig.suptitle('Student Well-being and Performance Analysis', fontsize=20, fontweight='bold')

# --- 1. SCATTER PLOT: Study vs Sleep ---
# Shows correlation and how stress levels cluster


# --- 2. GROUPED BAR CHART: Averages by Stress ---
# Shows the clear difference in averages between groups
melted_df = df.melt(id_vars='Stress_Status', value_vars=['Hours_Studied', 'Hours_Sleep'])
sns.barplot(ax=axes[0, 1], data=melted_df, x='variable', y='value', hue='Stress_Status', 
            palette='viridis', errorbar=None)
axes[0, 1].set_title('Average Hours by Stress Level', fontsize=14)
axes[0, 1].set_xlabel('Category')
axes[0, 1].set_ylabel('Average Hours')

# --- 3. HISTOGRAM: Sleep Distribution ---
# Includes Mean (solid) and Median (dashed) lines for context
sns.histplot(ax=axes[1, 0], data=df, x='Hours_Sleep', kde=True, color='skyblue')
axes[1, 0].axvline(df['Hours_Sleep'].mean(), color='red', linestyle='-', label='Mean')
axes[1, 0].axvline(df['Hours_Sleep'].median(), color='black', linestyle='--', label='Median')
axes[1, 0].set_title('Distribution of Sleep Hours', fontsize=14)
axes[1, 0].legend()

# --- 4. BOX PLOT: Identifying Outliers ---
# Visualizes the range, quartiles, and extremes
sns.boxplot(ax=axes[1, 1], data=df[['Hours_Studied', 'Hours_Sleep']], palette='Set2')
axes[1, 1].set_title('Range and Variance of Habits', fontsize=14)
axes[1, 1].set_ylabel('Hours')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
import pandas as pd

# 1. Processing the data
df = pd.DataFrame(dataset)
df['Stress_Encoded'] = df['Stress'].map({'No': 0, 'Yes': 1})

# 2. Calculating statistics
mean = df.mean(numeric_only=True)
median = df.median(numeric_only=True)
mode = df.mode(numeric_only=True).iloc[0]
std_dev = df.std(numeric_only=True)

# 3. Formatting for Stakeholders
print("--- STAKEHOLDER SUMMARY REPORT ---")

# Specific formatting for Time-based columns
time_cols = ['Hours_Studied', 'Hours_Sleep']

for col in time_cols:
    if col in df.columns:
        print(f"\n[{col.replace('_', ' ')}]")
        print(f"  - Average: {mean[col]:.2f} hours")
        print(f"  - Typical (Median): {median[col]:.1f} hours")
        print(f"  - Most Common: {mode[col]} hours")
        print(f"  - Variation (Std Dev): {std_dev[col]:.2f} hours")

# Specific formatting for Binary/Categorical columns (Stress)
if 'Stress_Encoded' in df.columns:
    print(f"\n[Stress Level]")
    print(f"  - Percentage Stressed: {mean['Stress_Encoded']*100:.1f}%")
    print(f"  - Most Common Status: {'Stressed' if mode['Stress_Encoded'] == 1 else 'Not Stressed'}")

# Formatting for other numeric columns (e.g., Scores)
other_cols = [c for c in df.select_dtypes(include=['number']).columns 
              if c not in time_cols and c != 'Stress_Encoded']

for col in other_cols:
    print(f"\n[{col.replace('_', ' ')}]")
    print(f"  - Average Score: {mean[col]:.2f}")
    print(f"  - Most Frequent Score: {mode[col]}")
# Out:
# --- STAKEHOLDER SUMMARY REPORT ---
#
# [Hours Studied]
#   - Average: 19.48 hours
#   - Typical (Median): 19.4 hours
#   - Most Common: 17.7 hours
#   - Variation (Std Dev): 4.54 hours
#
# [Hours Sleep]
#   - Average: 7.01 hours
#   - Typical (Median): 7.1 hours
#   - Most Common: 7.3 hours
#   - Variation (Std Dev): 1.38 hours
#
# [Stress Level]
#   - Percentage Stressed: 32.0%
#   - Most Common Status: Not Stressed
#
# [Caffeine Intake]
#   - Average Score: 1.94
#   - Most Frequent Score: 1.0
#
# [Exam Score]
#   - Average Score: 88.74
#   - Most Frequent Score: 100.0

# %%
summary = df.skew(numeric_only=True).to_frame(name='Skewness')#asymmetry of data for each column
summary['Kurtosis'] = df.kurtosis(numeric_only=True)#mesure prencense of outliers
#plot
summary.plot(kind='bar', figsize=(10, 5), title='Skewness and Kurtosis Overview')
plt.axhline(y=0, color='black', linestyle='--')
plt.ylabel('Value')
plt.grid(True)

# %%
#display sum of miss value per column
print("\n","Missing Values per column", df.isnull().sum())

#Total 
print("\n","Total:", df.isnull().sum().sum())

#display total percentage
print("\n", np.round(df.isnull().sum().mean(), 4), " % Total percentage of missing values")
# Out:
#  Missing Values per column Hours_Studied      0
# Hours_Sleep        0
# Caffeine_Intake    0
# Stress             0
# Exam_Score         0
# Stress_Encoded     0
# dtype: int64
#
#  Total: 0
#
#  0.0  % Total percentage of missing values
